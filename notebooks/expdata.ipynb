# %%
import sys
import os
import torch
import pandas as pd
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm

# CORRECTED IMPORTS
from transformers import BertForSequenceClassification, BertTokenizer
from torch.optim import AdamW 

# Path Setup
project_root = r"E:\Work\Uncertainity\RUA"
if project_root not in sys.path:
    sys.path.append(project_root)

# Device configuration
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")

# Verification of Data Path
data_dir = os.path.join(project_root, "data", "noisy")
if os.path.exists(data_dir):
    print(f"Data directory found: {data_dir}")
    print("Files available:", os.listdir(data_dir))
else:
    print(f"CRITICAL: Directory not found at {data_dir}. Check your path!")
# Out:
# Using device: cpu
# Data directory found: E:\Work\Uncertainity\RUA\data\noisy
# Files available: ['train_noise_10.csv', 'train_noise_20.csv', 'train_noise_30.csv']

# %%
import sys
import os


sys.path.append(os.path.abspath("../"))

from baseline_main import train_baseline

# %%
train_baseline(10)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 train_baseline(10)
#
# File e:\Work\Uncertainity\RUA\baseline_main.py:11, in train_baseline(noise_level)
#       9 def train_baseline(noise_level):
# ---> 11     model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2).to(DEVICE)
#      12     tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#      13     optimizer = AdamW(model.parameters(), lr=2e-5)
#
# ...

# %%
import torch

if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    print(f"CUDA is available! Training on: {torch.cuda.get_device_name(0)}")
else:
    DEVICE = torch.device("cpu")
    print("CUDA not found. Check your NVIDIA drivers.")
# Out:
# CUDA not found. Check your NVIDIA drivers.

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 2.8.0
# Uninstalling torch-2.8.0:
#   Successfully uninstalled torch-2.8.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Predator\AppData\Local\Programs\Python\Python311\Lib\site-packages\~orch'.
# You can safely remove it manually.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
